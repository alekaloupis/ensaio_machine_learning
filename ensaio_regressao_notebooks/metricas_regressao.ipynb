# %% [markdown]
# # 1. Imports

# %%
import pandas as pd
import pickle

# %% [markdown]
# # 2. Carregando os datasets dos algoritmos

# %%
def Load_Dataset(file):
    file = file
    with open (file, 'rb') as arq: 
        df = pickle.load(arq)
    return df

# %% [markdown]
# ### 2.1 Linear Regression

# %%
df_linear_regression_train = Load_Dataset('arquivo_linear_regression_train.pkl')
df_linear_regression_train
# Out:
#           Linear Regression
# r2_score             0.0461
# mse                455.9961
# rmse                21.0000
# mae                 16.9982
# mape                 8.6532

# %%
df_linear_regression_val = Load_Dataset('arquivo_linear_regression_val.pkl')
df_linear_regression_val
# Out:
#           Linear Regression
# r2_score             0.0523
# mse                461.4277
# rmse                21.0000
# mae                 17.1300
# mape                 8.5219

# %%
df_linear_regression_test = Load_Dataset('arquivo_linear_regression_test.pkl')
df_linear_regression_test
# Out:
#           Linear Regression
# r2_score             0.0399
# mse                458.4470
# rmse                21.0000
# mae                 17.0398
# mape                 8.6825

# %% [markdown]
# ### 2.2 Linear Regression Lasso

# %%
df_lasso_train = Load_Dataset('arquivo_lasso_train.pkl')
df_lasso_train
# Out:
#           Linear Regression Lasso
# r2_score                   0.0074
# mse                      474.4748
# rmse                      22.0000
# mae                       17.3055
# mape                       8.7367

# %%
df_lasso_val = Load_Dataset('arquivo_lasso_val.pkl')
df_lasso_val
# Out:
#           Linear Regression Lasso
# r2_score                   0.0296
# mse                      463.3853
# rmse                      22.0000
# mae                       17.0933
# mape                       8.6773

# %%
df_lasso_test = Load_Dataset('arquivo_lasso_test.pkl')
df_lasso_test
# Out:
#           Linear Regression Lasso
# r2_score                   0.0332
# mse                      470.7580
# rmse                      22.0000
# mae                       17.2587
# mape                       8.6533

# %% [markdown]
# ### 2.3 Linear Regression Ridge

# %%
df_ridge_train = Load_Dataset('arquivo_ridge_train.pkl')
df_ridge_train
# Out:
#           Linear Regression Ridge
# r2_score                   0.0461
# mse                      456.0000
# rmse                      21.0000
# mae                       17.0000
# mape                       8.6500

# %%
df_ridge_val = Load_Dataset('arquivo_ridge_val.pkl')
df_ridge_val
# Out:
#           Linear Regression Ridge
# r2_score                   0.0399
# mse                      458.4500
# rmse                      21.0000
# mae                       17.0400
# mape                       8.6800

# %%
df_ridge_test = Load_Dataset('arquivo_ridge_test.pkl')
df_ridge_test
# Out:
#           Linear Regression Ridge
# r2_score                   0.0512
# mse                      461.9900
# rmse                      21.0000
# mae                       17.1400
# mape                       8.5300

# %% [markdown]
# ### 2.4 Linear Regression Elastic Net

# %%
df_elastic_net_train = Load_Dataset('arquivo_elastic_net_train.pkl')
df_elastic_net_train
# Out:
#           Linear Regression Elastic Net
# r2_score                         0.0078
# mse                            474.2700
# rmse                            22.0000
# mae                             17.3000
# mape                             8.7300

# %%
df_elastic_net_test = Load_Dataset('arquivo_elastic_net_test.pkl')
df_elastic_net_test
# Out:
#           Linear Regression Elastic Net
# r2_score                         0.0511
# mse                            462.0300
# rmse                            21.0000
# mae                             17.1400
# mape                             8.5400

# %%
df_elastic_net_val = Load_Dataset('arquivo_elastic_net_val.pkl')
df_elastic_net_val
# Out:
#           Linear Regression Elastic Net
# r2_score                         0.0399
# mse                            458.4400
# rmse                            21.0000
# mae                             17.0400
# mape                             8.6800

# %% [markdown]
# ### 2.5 Polinomial Regression

# %%
df_poly_regression_train = Load_Dataset('arquivo_poly_regression_train.pkl')
df_poly_regression_train
# Out:
#           Polinomial Regression
# r2_score                 0.0942
# mse                    432.9862
# rmse                    20.8083
# mae                     16.4580
# mape                     8.3505

# %%
df_poly_regression_test = Load_Dataset('arquivo_poly_regression_test.pkl')
df_poly_regression_test
# Out:
#           Polinomial Regression
# r2_score                 0.0909
# mse                    442.6414
# rmse                    21.0390
# mae                     16.7364
# mape                     8.2770

# %%
df_poly_regression_val = Load_Dataset('arquivo_poly_regression_val.pkl')
df_poly_regression_val
# Out:
#           Polinomial Regression
# r2_score                 0.0665
# mse                    445.7682
# rmse                    21.1132
# mae                     16.7499
# mape                     8.5479

# %% [markdown]
# ### 2.6 Polinomial Regression Lasso

# %%
df_poly_regression_lasso_train = Load_Dataset('arquivo_poly_regression_lasso_train.pkl')
df_poly_regression_lasso_train
# Out:
#           Polinomial Regression Lasso
# r2_score                       0.0091
# mse                          473.6388
# rmse                          21.7632
# mae                           17.2854
# mape                           8.6997

# %%
df_poly_regression_lasso_test = Load_Dataset('arquivo_poly_regression_lasso_test.pkl')
df_poly_regression_lasso_test
# Out:
#           Polinomial Regression Lasso
# r2_score                       0.0854
# mse                          445.3322
# rmse                          21.1029
# mae                           16.7857
# mape                           8.3421

# %%
df_poly_regression_lasso_val = Load_Dataset('arquivo_poly_regression_lasso_val.pkl')
df_poly_regression_lasso_val
# Out:
#           Polinomial Regression Lasso
# r2_score                       0.0685
# mse                          444.8150
# rmse                          21.0906
# mae                           16.7324
# mape                           8.5910

# %% [markdown]
# ### 2.7 Polinomial Regression Ridge

# %%
df_poly_regression_ridge_train = Load_Dataset('arquivo_poly_regression_ridge_train.pkl')
df_poly_regression_ridge_train
# Out:
#           Polinomial Regression Ridge
# r2_score                       0.0932
# mse                          433.4755
# rmse                          20.8201
# mae                           16.4720
# mape                           8.3727

# %%
df_poly_regression_ridge_test = Load_Dataset('arquivo_poly_regression_ridge_test.pkl')
df_poly_regression_ridge_test
# Out:
#           Polinomial Regression Ridge
# r2_score                       0.0906
# mse                          442.7649
# rmse                          21.0420
# mae                           16.7377
# mape                           8.2971

# %%
df_poly_regression_ridge_val = Load_Dataset('arquivo_poly_regression_ridge_val.pkl')
df_poly_regression_ridge_val
# Out:
#           Polinomial Regression Ridge
# r2_score                       0.0677
# mse                          445.2026
# rmse                          21.0998
# mae                           16.7382
# mape                           8.5638

# %% [markdown]
# ### 2.8 Polinomial Regression Elastic Net

# %%
df_poly_regression_elastic_net_train = Load_Dataset('arquivo_poly_regression_elastic_net_train.pkl')
df_poly_regression_elastic_net_train
# Out:
#           Polinomial Regression Elastic Net
# r2_score                             0.0128
# mse                                471.8783
# rmse                                21.7228
# mae                                 17.2442
# mape                                 8.6788

# %%
df_poly_regression_elastic_net_test = Load_Dataset('arquivo_poly_regression_elastic_net_teste.pkl')
df_poly_regression_elastic_net_test
# Out:
#           Polinomial Regression Elastic Net
# r2_score                             0.0447
# mse                                465.1317
# rmse                                21.5669
# mae                                 17.1160
# mape                                 8.6281

# %%
df_poly_regression_elastic_net_val = Load_Dataset('arquivo_poly_regression_elastic_net_val.pkl')
df_poly_regression_elastic_net_val
# Out:
#           Polinomial Regression Elastic Net
# r2_score                             0.0428
# mse                                457.0769
# rmse                                21.3794
# mae                                 16.9356
# mape                                 8.6452

# %% [markdown]
# ### 2.9 Decision Tree Regressor

# %%
df_decision_tree_regressor_train = Load_Dataset('arquivo_decision_tree_regressor_train.pkl')
df_decision_tree_regressor_train
# Out:
#           Decision Tree Regressor
# r2_score                   0.9918
# mse                        3.9404
# rmse                       1.9850
# mae                        0.2141
# mape                       0.0826

# %%
df_decision_tree_regressor_test = Load_Dataset('arquivo_decision_tree_regressor_teste.pkl')
df_decision_tree_regressor_test
# Out:
#           Decision Tree Regressor
# r2_score                   0.0905
# mse                      442.8484
# rmse                      21.0440
# mae                       16.8298
# mape                       7.8832

# %%
df_decision_tree_regressor_val = Load_Dataset('arquivo_decision_tree_regressor_val.pkl')
df_decision_tree_regressor_val
# Out:
#           Decision Tree Regressor
# r2_score                   0.0636
# mse                      447.1613
# rmse                      21.1462
# mae                       16.8435
# mape                       8.3958

# %% [markdown]
# ### 2.10 Random Forest Regressor

# %%
df_rf_regressor_train = Load_Dataset('arquivo_rf_regressor_train.pkl')
df_rf_regressor_train
# Out:
#           Random Forest Regressor
# r2_score                   0.9026
# mse                       46.5433
# rmse                       6.8223
# mae                        4.8807
# mape                       2.6075

# %%
df_rf_regressor_test = Load_Dataset('arquivo_rf_regressor_teste.pkl')
df_rf_regressor_test
# Out:
#           Random Forest Regressor
# r2_score                   0.4024
# mse                      290.9508
# rmse                      17.0573
# mae                       12.2606
# mape                       6.3657

# %%
df_rf_regressor_val = Load_Dataset('arquivo_rf_regressor_val.pkl')
df_rf_regressor_val
# Out:
#           Random Forest Regressor
# r2_score                   0.3351
# mse                      317.4923
# rmse                      17.8183
# mae                       13.0087
# mape                       7.0751

# %% [markdown]
# # 3. Concatenando os dataframes

# %% [markdown]
# ### 3.1 Datasets de treinamento

# %%
df_train = pd.concat([df_linear_regression_train, df_lasso_train, df_ridge_train,df_elastic_net_train,
                      df_poly_regression_train, df_poly_regression_lasso_train, df_poly_regression_ridge_train,
                     df_poly_regression_elastic_net_train, df_decision_tree_regressor_train,
                     df_rf_regressor_train], axis = 1)

# %%
df_train
# Out:
#           Linear Regression  Linear Regression Lasso  Linear Regression Ridge  \
# r2_score             0.0461                   0.0074                   0.0461
# mse                455.9961                 474.4748                 456.0000
# rmse                21.0000                  22.0000                  21.0000
# mae                 16.9982                  17.3055                  17.0000
# mape                 8.6532                   8.7367                   8.6500
#
#           Linear Regression Elastic Net  Polinomial Regression  \
# r2_score                         0.0078                 0.0942
# mse                            474.2700               432.9862
# rmse                            22.0000                20.8083
# mae                             17.3000                16.4580
# mape                             8.7300                 8.3505
#
#           Polinomial Regression Lasso  Polinomial Regression Ridge  \
# ...

# %% [markdown]
# ### 3.2 Datasets de validação

# %%
df_val = pd.concat([df_linear_regression_val, df_lasso_val, df_ridge_val,df_elastic_net_val,
                      df_poly_regression_val, df_poly_regression_lasso_val, df_poly_regression_ridge_val,
                   df_poly_regression_elastic_net_val, df_decision_tree_regressor_val,
                    df_rf_regressor_val], axis = 1)

# %%
df_val
# Out:
#           Linear Regression  Linear Regression Lasso  Linear Regression Ridge  \
# r2_score             0.0523                   0.0296                   0.0399
# mse                461.4277                 463.3853                 458.4500
# rmse                21.0000                  22.0000                  21.0000
# mae                 17.1300                  17.0933                  17.0400
# mape                 8.5219                   8.6773                   8.6800
#
#           Linear Regression Elastic Net  Polinomial Regression  \
# r2_score                         0.0399                 0.0665
# mse                            458.4400               445.7682
# rmse                            21.0000                21.1132
# mae                             17.0400                16.7499
# mape                             8.6800                 8.5479
#
#           Polinomial Regression Lasso  Polinomial Regression Ridge  \
# ...

# %% [markdown]
# ### 3.3 Datasets de teste

# %%
df_test = pd.concat([df_linear_regression_test, df_lasso_test, df_ridge_test,df_elastic_net_test,
                      df_poly_regression_test, df_poly_regression_lasso_test, df_poly_regression_ridge_test,
                    df_poly_regression_elastic_net_test, df_decision_tree_regressor_test,
                    df_rf_regressor_test], axis = 1)

# %%
df_test
# Out:
#           Linear Regression  Linear Regression Lasso  Linear Regression Ridge  \
# r2_score             0.0399                   0.0332                   0.0512
# mse                458.4470                 470.7580                 461.9900
# rmse                21.0000                  22.0000                  21.0000
# mae                 17.0398                  17.2587                  17.1400
# mape                 8.6825                   8.6533                   8.5300
#
#           Linear Regression Elastic Net  Polinomial Regression  \
# r2_score                         0.0511                 0.0909
# mse                            462.0300               442.6414
# rmse                            21.0000                21.0390
# mae                             17.1400                16.7364
# mape                             8.5400                 8.2770
#
#           Polinomial Regression Lasso  Polinomial Regression Ridge  \
# ...
